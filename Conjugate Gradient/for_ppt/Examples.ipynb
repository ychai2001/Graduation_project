# %% [markdown]
# # 예제

# %%
from make_sys import *
from sparse_character import *
from scipy.io import loadmat

# %%
content = loadmat('bcsstk13.mat')
a = content['Problem'][0, 0]['A']

content2 = loadmat('pdb1HYS.mat')
b = content2['Problem'][0, 0]['A']

# %%
character(a)
character(b)
# Out:
# 최대 고유값 : 3114811969167.2627
# 최소 고유값 : 284.3328126411898
#
# Condition Number : 10954810105.21976
# Average Diagonlity : 0.44679496024437027
# Bandwidth : 2501
# Non-zeros Ratio : 2.0907979019987244 %
# 최대 고유값 : 352.39373935660205
# 최소 고유값 : 9.970485800918382e-10
#
# Condition Number : 353436880000.51416
# Average Diagonlity : 0.39078202408647617
# Bandwidth : 68129
# Non-zeros Ratio : 0.3276106104554356 %

# %%
cal_time(a)
# Out:
# Exact solution = [0.04263136 0.7802235  0.99348545 ... 0.08282245 0.98857546 0.22152609]
#
# CPU solution L2 Error = 14.576764106750488
# GPU solution L2 Error = 14.457863807678223
#
# cpu 계산시간 : 0.4836893558502197
# gpu 계산시간 : 4.220543766021729
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cal_time(a)
#
# File c:\Users\ychai\CFD\cuda\2nd_Semester\make_sys.py:160, in cal_time(a)
#     158         print(f'cpu 계산시간 : {t_cpu/5}')
#     159         print(f'gpu 계산시간 : {t_gpu/5}')
# --> 160         raise ValueError(f"Solution doesn't match : {diff}")
#     162 else:
#     163     raise ValueError('Solution not converged')
#
# ValueError: Solution doesn't match : 0.25214502215385437

# %%
cal_time(b)
# Out:
# Exact solution = [0.9023488  0.5791708  0.9026375  ... 0.5631871  0.5742523  0.49470788]
#
# CPU solution L2 Error = 95.36306762695312
# GPU solution L2 Error = 95.36305236816406
#
# cpu 계산시간 : 1.0847713470458984
# gpu 계산시간 : 0.2461531639099121
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cal_time(b)
#
# File c:\Users\ychai\CFD\cuda\2nd_Semester\make_sys.py:160, in cal_time(a)
#     158         print(f'cpu 계산시간 : {t_cpu/5}')
#     159         print(f'gpu 계산시간 : {t_gpu/5}')
# --> 160         raise ValueError(f"Solution doesn't match : {diff}")
#     162 else:
#     163     raise ValueError('Solution not converged')
#
# ValueError: Solution doesn't match : 0.0006646827096119523

# %%
plot_sparse(a)
